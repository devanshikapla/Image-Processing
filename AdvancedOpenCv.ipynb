# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
cv.imshow('Devanshi' , gray)
cv.waitKey(0)

# %%
#BGR to HSV (hue saturation value)
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')

hsv = cv.cvtColor(img , cv.COLOR_BGR2HSV)

cv.imshow('DEVANSHI ' , hsv)
cv.waitKey(0)

# %%
#BGR to lab
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')

hsv = cv.cvtColor(img , cv.COLOR_BGR2LAB)

cv.imshow('DEVANSHI ' , hsv)
cv.waitKey(0)

# %%
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

plt.imshow(img)
plt.show()
cv.waitKey(0)

# conversion of bgr to rgb matplotlib percieves image in the form of bgr where as cv2 percieves image in the for of rgb

# %%
#BGR to RGB
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')

hsv = cv.cvtColor(img , cv.COLOR_BGR2RGB)

cv.imshow('RGB' , hsv)

plt.imshow(hsv)
plt.show()
cv.waitKey()

# %%
#Gray scale cant be converted directly to hsv but first can be converted to bgr then to hsv

# %%
#color channel
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

#open cv allows to split image into three rgb components

b,g,r = cv.split(img)
blank = np.zeros(img.shape[:2] , dtype = 'uint8')

blue = cv.merge([b, blank , blank])
green = cv.merge([blank, g , blank])
red = cv.merge([blank , blank , red])


cv.imshow('Blue' , blue)
cv.imshow('Red' , red)
cv.imshow('Green' , green)

print(img.shape)
print(b.shape)
print(g.shape)
print(r.shape)
merged = cv.merge([b,g,r])

cv.imshow('Merged' , merged)
cv.waitKey(0)
# Out:
# (1280, 720, 3)
# (1280, 720)
# (1280, 720)
# (1280, 720)

# %%
#blur and smooth an image
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)


#Averaging

average = cv.blur(img , (3,3))
#gaussian blur
gauss = cv.GaussianBlur(img , (7 , 7), 0 )

#medium blur
median = cv.medianBlur(img , 7)

cv.inshow('Median Blur' , median)

#Bilateral bluring bluring with retained edges as well

bilateral = cv.bilateralFilter(img , 5 , 15 , 15)
cv.imshow('Gaussian Blur' , gauss)
cv.imshow('Average Blur' , average )
cv.waitKey(0)

# %%
#Bitwise operator

import cv2 as cv
import numpy as np


blank = np.zeros((400 , 400) , dtype='uint8');

rectangle = cv.rectangle(blank.copy() , (30,30) , (370 , 370) , 255 , -1)
circle = cv.circle(blank.copy() , (200 , 200) , 200 , 255 , -1)
cv.imshow('rectangle' , rectangle)
cv.imshow('circle' , circle)



#& 

#this found the intersecting regions 

# bitwise_and = cv.bitwise_and(rectangle , circle)
# cv.imshow('bitwise_and' , bitwise_and)
# cv.waitKey(0)


#|

#this found the non-intersecting regions and intersecting regions

# bitwise_or = cv.bitwise_or(rectangle , circle)
# cv.imshow('bitwise_or' , bitwise_or)
# cv.waitKey(0)


#^  

#this finds non intersecting regions


# bitwise_xor = cv.bitwise_xor(rectangle , circle)
# cv.imshow('bitwise_xor' , bitwise_xor)
# cv.waitKey(0)

# not
#inverts the binary color 
bitwise_not = cv.bitwise_not(rectangle)
cv.imshow('bitwise_not' , bitwise_not)
cv.waitKey(0)

# %%
#masking allows to focus on certain part of images 

import cv2 as cv
import numpy as np
img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

blank = np.zeros(img.shape[:2] , dtype = 'uint8')

cv.imshow('Blank image' , blank)

mask = cv.circle(blank , (img.shape[1]//2 , img.shape[0]//2 ) , 100 , 255 , -1)

cv.imshow('Mask ' , mask)

masked = cv.bitwise_and(img , img , mask = mask)
cv.imshow('Masked Image' , masked)
cv.waitKey(0)

# %%
#histogram computations 
#histogram allows you to view the distributions of pixel intensity in the image


import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt


img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

#blank = np.zeros( img.shape[:2] , dtype = 'uint8')
gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

#mask = cv.circle(blank , (img.shape[1]//2 , img.shape[0]//2 ) , 100 , 255 , -1)

#cv.imshow('Mask' , mask)
cv.imshow('Gray' , gray)

gray_hist = cv.calcHist([gray] , [0] , None , [256] , [0,256]);

plt.figure()

plt.title('Gray Scale Histogram')

plt.xlabel('Binary intervals of pixel intensity ')
plt.ylabel('# of pixels')

plt.plot(gray_hist)

plt.xlim([0,256])

plt.show()

cv.waitKey(0)

# %%
#histogram computations 
#histogram allows you to view the distributions of pixel intensity in the image


import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt


img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

blank = np.zeros( img.shape[:2] , dtype = 'uint8')
gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

circle  = cv.circle(blank , (img.shape[1]//2 , img.shape[0]//2 ) , 100 , 255 , -1)
mask = cv.bitwise_and(gray , gray , mask = circle)
cv.imshow('Mask' , mask)
cv.imshow('Gray' , gray)

gray_hist = cv.calcHist([gray] , [0] , mask , [256] , [0,256]);

plt.figure()

plt.title('Gray Scale Histogram')

plt.xlabel('Binary intervals of pixel intensity ')
plt.ylabel('# of pixels')

plt.plot(gray_hist)

plt.xlim([0,256])

plt.show()

cv.waitKey(0)

# %%
#thresholding

#binarization of an image, converting image to the binary form


# A common approach is taking pixels of the image and comparing to threasholding value if it is less than the threashold then set it to 0 else set it to 1


import cv2 as cv


img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)


#simple threashold

gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

cv.imshow('Gray' , gray)

# threshold , thresh  = cv.threshold(gray , 150 , 255 , cv.THRESH_BINARY )
# cv.imshow('Simple threshold' , thresh )





# threshold , thresh_inverse  = cv.threshold(gray , 150 , 255 , cv.THRESH_BINARY_INV )
# cv.imshow('Simple threshold' , thresh_inverse )


#Adaptive threshold

adaptive_thresh1 = cv.adaptiveThreshold(gray , 255 , cv.ADAPTIVE_THRESH_MEAN_C , cv.THRESH_BINARY , 11 , 3)
cv.imshow('adaptiveThreshold' , adaptive_thresh1)
adaptive_thresh = cv.adaptiveThreshold(gray , 255 , cv.ADAPTIVE_THRESH_MEAN_C , cv.THRESH_BINARY_INV , 11 , 3)
cv.imshow('adaptiveThreshold' , adaptive_thresh)
cv.waitKey(0)

# %%
#edge detection in open cv
import cv2 as cv
import numpy as np


img = cv.imread('/Users/oro/Downloads/WhatsApp Image 2023-06-24 at 11.27.47.jpeg')
cv.imshow('Devanshi' , img)

gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
cv.imshow('Gray' , gray)

#laplacian

lap = cv.Laplacian(gray , cv.CV_64F)

lap = np.uint8(np.absolute(lap))

cv.imshow('Laplacian' , lap)

#sobel

sobelx = cv.Sobel(gray , cv.CV_64F , 1 , 0)
sobely = cv.Sobel(gray , cv.CV_64F , 0 , 1)

combined_sobel = cv.bitwise_or(sobelx , sobely)
cv.imshow('SOBELX' , sobelx)
cv.imshow('SOBELY' , sobely)
cv.imshow('Combined' , combined_sobel)
cv.waitKey(0)
